# %% [markdown]
# # MS Paint is Underrated
# ### Phase1

# %%
# %pylab inline
import imageio
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pallete = imread("palette.png")
axis('off')
print(pallete.shape, pallete.dtype)
imshow(pallete)
# Out:
# (1, 28, 3) float32

# %%
target = imread("starry-night-300.jpg")
imshow(target)
print(target.shape, target.dtype)
# Out:
# (238, 300, 3) uint8

# %%
png = np.ones((238,300,3))

for x in range(100000):
    i = random.randint(250)
    j = random.randint(300)
    rgb = pallete[0][random.randint(28)]
    png[i:i+4, j:j+4] = rgb
imshow(png)

# %%
imageio.imwrite('random100k.png', png)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
