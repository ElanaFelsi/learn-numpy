# %% [markdown]
# # Broadcasting Drill
# ### Phase 1

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
gray_arr = linspace(0, 1, 400)
print(a.shape)
ones_arr = np.ones(400)
print(b.shape)
# Out:
# (400,)
# (400,)

# %%
m = gray_arr * ones_arr[:,newaxis]
imshow(m, cm.gray)
colorbar()

# %%
m = gray_arr[:,newaxis] * ones_arr
imshow(m, cm.gray)
colorbar
# Out:
# <function matplotlib.pyplot.colorbar(mappable=None, cax=None, ax=None, **kw)>

# %%
m = (gray_arr + gray_arr[:,newaxis])/2
imshow(m, cm.gray)
colorbar()

# %%
m = (gray_arr + gray_arr[:,newaxis])/2 >= 0.5
imshow(m, cm.gray)

# %%
m = (gray_arr + gray_arr[:,newaxis])/2 %0.2 
imshow(m, cm.gray)
colorbar()

# %%
m = (gray_arr + gray_arr[:,newaxis])/2 %0.2 >= 0.1
imshow(m, cm.gray)
